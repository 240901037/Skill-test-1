# %%
import pandas as pd
data = {
'Time':[1,2,3,4,5],
'Electrode1':[10,12,11,14,13],
'Electrode2':[9,11,10,13,12],
'Electrode3':[8,10,9,12,11]
}
df = pd.DataFrame(data)
print("EEG Data")
print(df)
print("Mean values:")
print(df.mean())
print("Variance values:")
print(df.var())
print("Peak values:")
print(df.max())
# Out:
# EEG Data
#    Time  Electrode1  Electrode2  Electrode3
# 0     1          10           9           8
# 1     2          12          11          10
# 2     3          11          10           9
# 3     4          14          13          12
# 4     5          13          12          11
# Mean values:
# Time           3.0
# Electrode1    12.0
# Electrode2    11.0
# Electrode3    10.0
# dtype: float64
# Variance values:
# Time          2.5
# Electrode1    2.5
# Electrode2    2.5
# Electrode3    2.5
# dtype: float64
# Peak values:
# Time           5
# Electrode1    14
# Electrode2    13
# Electrode3    12
# dtype: int64
